# %%
import cv2

# %%
from deepface import DeepFace

# %%
img=cv2.imread('happyboy.jpeg')

# %%
import matplotlib.pyplot as pd

# %%
pd.imshow(img)

# %%
pd.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions=DeepFace.analyze(img)
# Out:
# ...
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.48it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 4.70390289220024e-09,
#   'disgust': 4.5036264756555255e-11,
#   'fear': 8.03986210939911e-05,
#   'happy': 99.99972581863403,
#   'sad': 2.1248243164961877e-07,
#   'surprise': 7.607506638529493e-10,
#   'neutral': 0.00019595522644522134},
#  'dominant_emotion': 'happy',
#  'region': {'x': 56, 'y': 36, 'w': 121, 'h': 121},
#  'age': 19,
#  'gender': 'Man',
#  'race': {'asian': 0.19085064996033907,
#   'indian': 0.47909202985465527,
#   'black': 0.027835459331981838,
#   'white': 62.90145516395569,
#   'middle eastern': 16.376054286956787,
#   'latino hispanic': 20.0247123837471},
#  'dominant_race': 'white'}

# %%
predictions['emotion']
# Out:
# {'angry': 4.70390289220024e-09,
#  'disgust': 4.5036264756555255e-11,
#  'fear': 8.03986210939911e-05,
#  'happy': 99.99972581863403,
#  'sad': 2.1248243164961877e-07,
#  'surprise': 7.607506638529493e-10,
#  'neutral': 0.00019595522644522134}
